# %%
import pandas as pd

# %%
df=pd.read_csv("laptop_data.csv")

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
df=df.drop(columns={"Unnamed: 0"})

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Ram'] = df['Ram'].str.extract('(\d+)')
df['Ram'] = df['Ram'].astype(int)

# %%
df['Weight']=df['Weight'].str.replace("kg","")
df["Weight"]=df['Weight'].astype(float)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
# dtypes: float64(3), int32(1), object(7)
# memory usage: 107.0+ KB

# %%
import seaborn as sns

# %%
sns.distplot(df["Price"])
# Out:
# c:\users\tapan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
df["Company"].value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df["Company"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,6)) 

sns.barplot(x=df["Company"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Price'>

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df["TypeName"].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
df["TypeName"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,6)) 

sns.barplot(x=df["TypeName"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='TypeName', ylabel='Price'>

# %%
plt.figure(figsize=(20,6)) 

sns.barplot(x=df["Inches"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
sns.distplot(df["Inches"])
# Out:
# c:\users\tapan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
df["Inches"].value_counts()
# Out:
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 12.0      6
# 13.5      6
# 13.9      6
# 12.3      5
# 10.1      4
# 15.4      4
# 15.0      4
# 13.0      2
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# Name: Inches, dtype: int64

# %%
sns.scatterplot(x=df["Inches"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price'>

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df["ScreenResolution"].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %%
df["Touchscreen"]=df["ScreenResolution"].apply(lambda x:1 if "Touchscreen"in x else 0)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df["Touchscreen"].value_counts()
# Out:
# 0    1111
# 1     192
# Name: Touchscreen, dtype: int64

# %%
df["Touchscreen"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["Touchscreen"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Touchscreen', ylabel='Price'>

# %%
df["IPS"]=df["ScreenResolution"].apply(lambda x:1 if "IPS"in x else 0)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df["IPS"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["IPS"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='IPS', ylabel='Price'>

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
resolution=df["ScreenResolution"].str.split("x", expand=True)

# %%
df["xres"]=resolution[0]
df["yres"]=resolution[1]

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['xres'] = df['xres'].str.extract('(\d+)')

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  xres              1303 non-null   object
#  14  yres              1303 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(9)
# ...

# %%
df["xres"]=df["xres"].astype(int)
df["yres"]=df["yres"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  xres              1303 non-null   int32
#  14  yres              1303 non-null   int32
# dtypes: float64(3), int32(3), int64(2), object(7)
# ...

# %%
df.corr()["Price"]
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# IPS            0.252208
# xres           0.083832
# yres           0.552809
# Name: Price, dtype: float64

# %%
df["pixelperinch"]=(((df["xres"]**2)+(df["yres"]**2))**0.5/df["Inches"])

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float64
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  xres              1303 non-null   int32
#  14  yres              1303 non-null   int32
#  15  pixelperinch      1303 non-null   float64
# ...

# %%
df=df.drop(columns={"ScreenResolution","xres","yres","Inches"})

# %%
df["Cpu"].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df["Cpu"].unique()
# Out:
# array(['Intel Core i5 2.3GHz', 'Intel Core i5 1.8GHz',
#        'Intel Core i5 7200U 2.5GHz', 'Intel Core i7 2.7GHz',
#        'Intel Core i5 3.1GHz', 'AMD A9-Series 9420 3GHz',
#        'Intel Core i7 2.2GHz', 'Intel Core i7 8550U 1.8GHz',
#        'Intel Core i5 8250U 1.6GHz', 'Intel Core i3 6006U 2GHz',
#        'Intel Core i7 2.8GHz', 'Intel Core M m3 1.2GHz',
#        'Intel Core i7 7500U 2.7GHz', 'Intel Core i7 2.9GHz',
#        'Intel Core i3 7100U 2.4GHz', 'Intel Atom x5-Z8350 1.44GHz',
#        'Intel Core i5 7300HQ 2.5GHz', 'AMD E-Series E2-9000e 1.5GHz',
#        'Intel Core i5 1.6GHz', 'Intel Core i7 8650U 1.9GHz',
#        'Intel Atom x5-Z8300 1.44GHz', 'AMD E-Series E2-6110 1.5GHz',
#        'AMD A6-Series 9220 2.5GHz',
#        'Intel Celeron Dual Core N3350 1.1GHz',
#        'Intel Core i3 7130U 2.7GHz', 'Intel Core i7 7700HQ 2.8GHz',
#        'Intel Core i5 2.0GHz', 'AMD Ryzen 1700 3GHz',
#        'Intel Pentium Quad Core N4200 1.1GHz',
# ...

# %%
df["cpu_short"]=df["Cpu"].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1303 non-null   object
#  1   TypeName      1303 non-null   object
#  2   Cpu           1303 non-null   object
#  3   Ram           1303 non-null   int32
#  4   Memory        1303 non-null   object
#  5   Gpu           1303 non-null   object
#  6   OpSys         1303 non-null   object
#  7   Weight        1303 non-null   float64
#  8   Price         1303 non-null   float64
#  9   Touchscreen   1303 non-null   int64
#  10  IPS           1303 non-null   int64
#  11  pixelperinch  1303 non-null   float64
#  12  cpu_short     1303 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(7)
# memory usage: 127.4+ KB

# %%
def getbrands(text):
    
    if text=="Intel Core i5" or text=="Intel Core i7" or text=="Intel Core i3 ":
        return text
    
    else:
        
        if text.split()[0]=="Intel":
            return "other intel"
        
        else:
            
            return "amd"

# %%
df["cpu brand"]=df["cpu_short"].apply(getbrands)

# %%
df
# Out:
#      Company            TypeName                                   Cpu  Ram  \
# 0      Apple           Ultrabook                  Intel Core i5 2.3GHz    8
# 1      Apple           Ultrabook                  Intel Core i5 1.8GHz    8
# 2         HP            Notebook            Intel Core i5 7200U 2.5GHz    8
# 3      Apple           Ultrabook                  Intel Core i7 2.7GHz   16
# 4      Apple           Ultrabook                  Intel Core i5 3.1GHz    8
# ...      ...                 ...                                   ...  ...
# 1298  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz    4
# 1299  Lenovo  2 in 1 Convertible            Intel Core i7 6500U 2.5GHz   16
# 1300  Lenovo            Notebook  Intel Celeron Dual Core N3050 1.6GHz    2
# 1301      HP            Notebook            Intel Core i7 6500U 2.5GHz    6
# 1302    Asus            Notebook  Intel Celeron Dual Core N3050 1.6GHz    4
#
# ...

# %%
df["cpu brand"].value_counts()
# Out:
# Intel Core i7    527
# Intel Core i5    423
# other intel      290
# amd               63
# Name: cpu brand, dtype: int64

# %%
df["cpu brand"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["cpu brand"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='cpu brand', ylabel='Price'>

# %%
df=df.drop(columns={"Cpu","cpu_short"})

# %%
#######  ram feature engineering

# %%
df["Ram"].value_counts()
# Out:
# 8     619
# 4     375
# 16    200
# 6      41
# 12     25
# 2      22
# 32     17
# 24      3
# 64      1
# Name: Ram, dtype: int64

# %%
df["Ram"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=df["Ram"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price'>

# %%
df.corr()["Ram"]["Price"]
# Out:
# 0.7430071352506955

# %%
df["Memory"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
df['second_word'] = df["Memory"].str.split().str[1]

# %%
df['second_word']
# Out:
# 0         SSD
# 1       Flash
# 2         SSD
# 3         SSD
# 4         SSD
#         ...
# 1298      SSD
# 1299      SSD
# 1300    Flash
# 1301      HDD
# 1302      HDD
# Name: second_word, Length: 1303, dtype: object

# %%
df['second_word'].unique()
# Out:
# array(['SSD', 'Flash', 'HDD', 'Hybrid'], dtype=object)

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Company       1303 non-null   object
#  1   TypeName      1303 non-null   object
#  2   Ram           1303 non-null   int32
#  3   Memory        1303 non-null   object
#  4   Gpu           1303 non-null   object
#  5   OpSys         1303 non-null   object
#  6   Weight        1303 non-null   float64
#  7   Price         1303 non-null   float64
#  8   Touchscreen   1303 non-null   int64
#  9   IPS           1303 non-null   int64
#  10  pixelperinch  1303 non-null   float64
#  11  cpu brand     1303 non-null   object
#  12  second_word   1303 non-null   object
# dtypes: float64(3), int32(1), int64(2), object(7)
# memory usage: 127.4+ KB

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df["Gpu"].unique()
# Out:
# array(['Intel Iris Plus Graphics 640', 'Intel HD Graphics 6000',
#        'Intel HD Graphics 620', 'AMD Radeon Pro 455',
#        'Intel Iris Plus Graphics 650', 'AMD Radeon R5',
#        'Intel Iris Pro Graphics', 'Nvidia GeForce MX150',
#        'Intel UHD Graphics 620', 'Intel HD Graphics 520',
#        'AMD Radeon Pro 555', 'AMD Radeon R5 M430',
#        'Intel HD Graphics 615', 'AMD Radeon Pro 560',
#        'Nvidia GeForce 940MX', 'Intel HD Graphics 400',
#        'Nvidia GeForce GTX 1050', 'AMD Radeon R2', 'AMD Radeon 530',
#        'Nvidia GeForce 930MX', 'Intel HD Graphics',
#        'Intel HD Graphics 500', 'Nvidia GeForce 930MX ',
#        'Nvidia GeForce GTX 1060', 'Nvidia GeForce 150MX',
#        'Intel Iris Graphics 540', 'AMD Radeon RX 580',
#        'Nvidia GeForce 920MX', 'AMD Radeon R4 Graphics', 'AMD Radeon 520',
#        'Nvidia GeForce GTX 1070', 'Nvidia GeForce GTX 1050 Ti',
#        'Nvidia GeForce MX130', 'AMD R4 Graphics',
# ...

# %%
df["Gpu brand"]=df["Gpu"].apply(lambda x:x.split()[0])

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  \
# 0      Apple           Ultrabook    8            128GB SSD
# 1      Apple           Ultrabook    8  128GB Flash Storage
# 2         HP            Notebook    8            256GB SSD
# 3      Apple           Ultrabook   16            512GB SSD
# 4      Apple           Ultrabook    8            256GB SSD
# ...      ...                 ...  ...                  ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD
# 1300  Lenovo            Notebook    2   64GB Flash Storage
# 1301      HP            Notebook    6              1TB HDD
# 1302    Asus            Notebook    4            500GB HDD
#
#                                Gpu       OpSys  Weight        Price  \
# 0     Intel Iris Plus Graphics 640       macOS    1.37   71378.6832
# 1           Intel HD Graphics 6000       macOS    1.34   47895.5232
# ...

# %%
df["Gpu brand"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df=df[df["Gpu brand"]!="ARM"]

# %%
df["Gpu brand"].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df["Gpu brand"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Gpu brand', ylabel='Price'>

# %%
df=df.drop(columns={"Gpu"})

# %%
df
# Out:
#      Company            TypeName  Ram               Memory       OpSys  \
# 0      Apple           Ultrabook    8            128GB SSD       macOS
# 1      Apple           Ultrabook    8  128GB Flash Storage       macOS
# 2         HP            Notebook    8            256GB SSD       No OS
# 3      Apple           Ultrabook   16            512GB SSD       macOS
# 4      Apple           Ultrabook    8            256GB SSD       macOS
# ...      ...                 ...  ...                  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD  Windows 10
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD  Windows 10
# 1300  Lenovo            Notebook    2   64GB Flash Storage  Windows 10
# 1301      HP            Notebook    6              1TB HDD  Windows 10
# 1302    Asus            Notebook    4            500GB HDD  Windows 10
#
#       Weight        Price  Touchscreen  IPS  pixelperinch      cpu brand  \
# ...

# %%
df["OpSys"].unique()
# Out:
# array(['macOS', 'No OS', 'Windows 10', 'Mac OS X', 'Linux', 'Android',
#        'Windows 10 S', 'Chrome OS', 'Windows 7'], dtype=object)

# %%
df["OpSys"].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
plt.figure(figsize=(20,6)) 
sns.barplot(x=df["OpSys"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='OpSys', ylabel='Price'>

# %%
def oscategory(text):
    
    if text=="Windows 10" or text=="Windows 7":
        return "windows"
    
    elif text=="macOS" or text=="Mac OS X":
        return "mac"
    
    else:
        return "linux/no-os/other"

# %%
df["os"]=df["OpSys"].apply(oscategory)

# %%
df
# Out:
#      Company            TypeName  Ram               Memory       OpSys  \
# 0      Apple           Ultrabook    8            128GB SSD       macOS
# 1      Apple           Ultrabook    8  128GB Flash Storage       macOS
# 2         HP            Notebook    8            256GB SSD       No OS
# 3      Apple           Ultrabook   16            512GB SSD       macOS
# 4      Apple           Ultrabook    8            256GB SSD       macOS
# ...      ...                 ...  ...                  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD  Windows 10
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD  Windows 10
# 1300  Lenovo            Notebook    2   64GB Flash Storage  Windows 10
# 1301      HP            Notebook    6              1TB HDD  Windows 10
# 1302    Asus            Notebook    4            500GB HDD  Windows 10
#
#       Weight        Price  Touchscreen  IPS  pixelperinch      cpu brand  \
# ...

# %%
df["os"].value_counts()
# Out:
# windows              1117
# linux/no-os/other     164
# mac                    21
# Name: os, dtype: int64

# %%
df=df.drop(columns={"OpSys"})

# %%
plt.figure(figsize=(20,6)) 
sns.barplot(x=df["os"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='os', ylabel='Price'>

# %%
df.corr()
# Out:
#                    Ram    Weight     Price  Touchscreen       IPS  \
# Ram           1.000000  0.383362  0.742905     0.118875  0.207949
# Weight        0.383362  1.000000  0.209867    -0.293004  0.018643
# Price         0.742905  0.209867  1.000000     0.192917  0.253320
# Touchscreen   0.118875 -0.293004  0.192917     1.000000  0.148026
# IPS           0.207949  0.018643  0.253320     0.148026  1.000000
# pixelperinch  0.188494 -0.447811  0.350885     0.413446  0.285385
#
#               pixelperinch
# Ram               0.188494
# Weight           -0.447811
# Price             0.350885
# Touchscreen       0.413446
# IPS               0.285385
# pixelperinch      1.000000

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      Company            TypeName  Ram               Memory  Weight  \
# 0      Apple           Ultrabook    8            128GB SSD    1.37
# 1      Apple           Ultrabook    8  128GB Flash Storage    1.34
# 2         HP            Notebook    8            256GB SSD    1.86
# 3      Apple           Ultrabook   16            512GB SSD    1.83
# 4      Apple           Ultrabook    8            256GB SSD    1.37
# ...      ...                 ...  ...                  ...     ...
# 1298  Lenovo  2 in 1 Convertible    4            128GB SSD    1.80
# 1299  Lenovo  2 in 1 Convertible   16            512GB SSD    1.30
# 1300  Lenovo            Notebook    2   64GB Flash Storage    1.50
# 1301      HP            Notebook    6              1TB HDD    2.19
# 1302    Asus            Notebook    4            500GB HDD    2.20
#
#             Price  Touchscreen  IPS  pixelperinch      cpu brand second_word  \
# 0      71378.6832            0    1    226.983005  Intel Core i5         SSD
# ...

# %%
#### memory ---> ssd hdd hybrid flash   ---> machine learning models apply

# %%
df["Memory"].unique()
# Out:
# array(['128GB SSD', '128GB Flash Storage', '256GB SSD', '512GB SSD',
#        '500GB HDD', '256GB Flash Storage', '1TB HDD',
#        '32GB Flash Storage', '128GB SSD +  1TB HDD',
#        '256GB SSD +  256GB SSD', '64GB Flash Storage',
#        '256GB SSD +  1TB HDD', '256GB SSD +  2TB HDD', '32GB SSD',
#        '2TB HDD', '64GB SSD', '1.0TB Hybrid', '512GB SSD +  1TB HDD',
#        '1TB SSD', '256GB SSD +  500GB HDD', '128GB SSD +  2TB HDD',
#        '512GB SSD +  512GB SSD', '16GB SSD', '16GB Flash Storage',
#        '512GB SSD +  256GB SSD', '512GB SSD +  2TB HDD',
#        '64GB Flash Storage +  1TB HDD', '180GB SSD', '1TB HDD +  1TB HDD',
#        '32GB HDD', '1TB SSD +  1TB HDD', '512GB Flash Storage',
#        '128GB HDD', '240GB SSD', '8GB SSD', '508GB Hybrid', '1.0TB HDD',
#        '512GB SSD +  1.0TB Hybrid', '256GB SSD +  1.0TB Hybrid'],
#       dtype=object)

# %%
 df.iloc[1075]
# Out:
# Company                Lenovo
# TypeName             Notebook
# Ram                         8
# Memory              1.0TB HDD
# Weight                    3.0
# Price                35111.52
# Touchscreen                 0
# IPS                         0
# pixelperinch       106.113062
# cpu brand       Intel Core i5
# second_word               HDD
# Gpu brand                 AMD
# os                    windows
# Name: 1075, dtype: object

# %%
df["Memory"]=df["Memory"].apply(lambda x: x.split("+"))

# %%
df.sample(50)
# Out:
#       Company            TypeName  Ram                   Memory  Weight  \
# 1007       HP           Ultrabook    8              [256GB SSD]    1.43
# 609      Acer            Notebook    4    [128GB Flash Storage]    1.60
# 2          HP            Notebook    8              [256GB SSD]    1.86
# 359      Dell            Notebook    8              [256GB SSD]    1.36
# 1009       HP            Notebook    4              [500GB HDD]    1.64
# 282    Lenovo              Gaming    8              [256GB SSD]    2.50
# 397    Lenovo            Notebook    8              [256GB SSD]    1.90
# 869      Dell         Workstation    8                [1TB HDD]    2.23
# 629      Dell            Notebook    8              [256GB SSD]    2.00
# 485    Lenovo            Notebook    8              [256GB SSD]    1.75
# 1147     Dell            Notebook    8              [256GB SSD]    2.18
# 1135   Lenovo            Notebook   16           [1.0TB Hybrid]    2.50
# ...

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Memory', 'Weight', 'Price',
#        'Touchscreen', 'IPS', 'pixelperinch', 'cpu brand', 'second_word',
#        'Gpu brand', 'os'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Company', 'TypeName', 'Ram', 'Memory', 'Weight', 'Price',
#        'Touchscreen', 'IPS', 'pixelperinch', 'cpu brand', 'second_word',
#        'Gpu brand', 'os'],
#       dtype='object')

# %%
# create empty lists for each column
ssd = []
hdd = []
hybrid = []
flash_storage = []

# loop through each array in the memory column
for array in df['Memory']:
    # initialize variables for each array
    array_ssd = 0
    array_hdd = 0
    array_hybrid = 0
    array_flash = 0
    
    # loop through each value in the array
    for val in array:
        # check for ssd
        if 'ssd' in val.lower():
            num = int(''.join(filter(str.isdigit, val)))
            array_ssd = num
            
        # check for hdd
        elif 'hdd' in val.lower():
            num = int(''.join(filter(str.isdigit, val)))
            array_hdd = num
            
        # check for hybrid
        elif 'hybrid' in val.lower():
            num = int(''.join(filter(str.isdigit, val)))
            array_hybrid = num
            
        # check for flash storage
        elif 'flash storage' in val.lower():
            num = int(''.join(filter(str.isdigit, val)))
            array_flash = num
            
    # append the values for each array to the corresponding list
    ssd.append(array_ssd)
    hdd.append(array_hdd)
    hybrid.append(array_hybrid)
    flash_storage.append(array_flash)

# add the new columns to the dataframe
df['ssd'] = ssd
df['hdd'] = hdd
df['hybrid'] = hybrid
df['flash storage'] = flash_storage

# %%
df
# Out:
#      Company            TypeName  Ram                 Memory  Weight  \
# 0      Apple           Ultrabook    8            [128GB SSD]    1.37
# 1      Apple           Ultrabook    8  [128GB Flash Storage]    1.34
# 2         HP            Notebook    8            [256GB SSD]    1.86
# 3      Apple           Ultrabook   16            [512GB SSD]    1.83
# 4      Apple           Ultrabook    8            [256GB SSD]    1.37
# ...      ...                 ...  ...                    ...     ...
# 1298  Lenovo  2 in 1 Convertible    4            [128GB SSD]    1.80
# 1299  Lenovo  2 in 1 Convertible   16            [512GB SSD]    1.30
# 1300  Lenovo            Notebook    2   [64GB Flash Storage]    1.50
# 1301      HP            Notebook    6              [1TB HDD]    2.19
# 1302    Asus            Notebook    4            [500GB HDD]    2.20
#
#             Price  Touchscreen  IPS  pixelperinch      cpu brand second_word  \
# ...

# %%
df.sample(50)
# Out:
#       Company            TypeName  Ram                        Memory  Weight  \
# 834    Lenovo            Notebook    8                   [256GB SSD]    1.32
# 544      Asus            Notebook    4                   [500GB HDD]    2.00
# 1159       HP  2 in 1 Convertible    8                   [512GB SSD]    1.48
# 88       Asus              Gaming   16       [128GB SSD ,   1TB HDD]    2.20
# 726      Dell            Notebook    8       [128GB SSD ,   1TB HDD]    2.20
# 126        HP            Notebook    8                     [1TB HDD]    1.63
# 276      Dell            Notebook    8       [128GB SSD ,   1TB HDD]    2.80
# 500      Asus             Netbook    4          [64GB Flash Storage]    1.20
# 924    Lenovo  2 in 1 Convertible    8                   [512GB SSD]    1.37
# 1081   Lenovo              Gaming   32  [512GB SSD ,   1.0TB Hybrid]    4.60
# 122    Lenovo            Notebook    8                   [256GB SSD]    2.20
# ...

# %%
df=df.drop(columns={"Memory"})

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
df["hdd"].value_counts()
# Out:
# 0      726
# 1      408
# 500    134
# 2       31
# 32       1
# 128      1
# 10       1
# Name: hdd, dtype: int64

# %%
df[df["hdd"]==10]
# Out:
#      Company  TypeName  Ram  Weight     Price  Touchscreen  IPS  pixelperinch  \
# 1075  Lenovo  Notebook    8     3.0  35111.52            0    0    106.113062
#
#           cpu brand second_word Gpu brand       os  ssd  hdd  hybrid  \
# 1075  Intel Core i5         HDD       AMD  windows    0   10       0
#
#       flash storage
# 1075              0

# %%
df["hybrid"].value_counts()
# Out:
# 0      1290
# 10       11
# 508       1
# Name: hybrid, dtype: int64

# %%
df["hybrid"]=df["hybrid"].apply(lambda x: 1 if x==10 else x)

# %%
df["hybrid"].value_counts()
# Out:
# 0      1290
# 1        11
# 508       1
# Name: hybrid, dtype: int64

# %%
df["hybrid"]=df["hybrid"].apply(lambda x: 1024 if x==1 else x)

# %%
df["hybrid"].value_counts()
# Out:
# 0       1290
# 1024      11
# 508        1
# Name: hybrid, dtype: int64

# %%
df["hdd"].value_counts()
# Out:
# 0      726
# 1      408
# 500    134
# 2       31
# 32       1
# 128      1
# 10       1
# Name: hdd, dtype: int64

# %%
df["hdd"]=df["hdd"].apply(lambda x: 1 if x==10 else x)

# %%
df["hdd"].value_counts()
# Out:
# 0      726
# 1      409
# 500    134
# 2       31
# 32       1
# 128      1
# Name: hdd, dtype: int64

# %%
df["hdd"]=df["hdd"].apply(lambda x: x*1024 if x==1 or x==2 else x)

# %%
df["hdd"].value_counts()
# Out:
# 0       726
# 1024    409
# 500     134
# 2048     31
# 32        1
# 128       1
# Name: hdd, dtype: int64

# %%
###   GB  :  ssd flash  hybrid  hdd

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
df=df.drop(columns={"second_word"})

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
df.corr()["Price"]
# Out:
# Ram              0.742905
# Weight           0.209867
# Price            1.000000
# Touchscreen      0.192917
# IPS              0.253320
# pixelperinch     0.350885
# ssd              0.552990
# hdd             -0.094530
# hybrid           0.007963
# flash storage   -0.040067
# Name: Price, dtype: float64

# %%
df["ssd"].value_counts()
# Out:
# 256    501
# 0      459
# 128    172
# 512    137
# 1       16
# 32       6
# 180      5
# 16       3
# 64       1
# 240      1
# 8        1
# Name: ssd, dtype: int64

# %%
sns.distplot(df["Weight"])
# Out:
# c:\users\tapan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df["Weight"],y=df["Price"])
# Out:
# <AxesSubplot:xlabel='Weight', ylabel='Price'>

# %%
plt.figure(figsize=(20,6))
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
df.corr()["Price"]
# Out:
# Ram              0.742905
# Weight           0.209867
# Price            1.000000
# Touchscreen      0.192917
# IPS              0.253320
# pixelperinch     0.350885
# ssd              0.552990
# hdd             -0.094530
# hybrid           0.007963
# flash storage   -0.040067
# Name: Price, dtype: float64

# %%
df=df.drop(columns={"flash storage","hybrid"})

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
sns.distplot(df["Price"])       ###  distribution plot, depicts the variation in the data distribution.
# Out:
# c:\users\tapan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
import numpy as np
sns.distplot(np.log(df["Price"]))
# Out:
# c:\users\tapan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
x=df.drop(columns={"Price"})
y=np.log(df["Price"])

# %%
###The main reason for applying a logarithmic transformation is to convert a skewed distribution of the target variable into a more normal distribution.

# %% [markdown]
# # #######   machine  learning models

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  IPS  \
# 183   Toshiba            Notebook    8    2.00            0    0
# 1141      MSI              Gaming    8    2.40            0    0
# 1049     Asus             Netbook    4    1.20            0    0
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1
# 878      Dell            Notebook    4    2.18            0    0
# ...       ...                 ...  ...     ...          ...  ...
# 466      Acer            Notebook    4    2.20            0    0
# 299      Asus           Ultrabook   16    1.63            0    0
# 493      Acer            Notebook    8    2.20            0    0
# 527    Lenovo            Notebook    8    2.20            0    0
# 1193    Apple           Ultrabook    8    0.92            0    1
#
#       pixelperinch      cpu brand Gpu brand                 os  ssd   hdd
# 183     100.454670  Intel Core i5     Intel            windows  128     0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

# %% [markdown]
# # Linear regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7950337985010538
# MAE 0.212807875187962

# %% [markdown]
# # Ridge Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8016274928879423
# MAE 0.21187294614110344

# %% [markdown]
# # Lasso Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7966535596554005
# MAE 0.21386010454581392

# %% [markdown]
# # KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8139905727062615
# MAE 0.1968390098814352

# %% [markdown]
# # Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8349861375300601
# MAE 0.18658508409696792

# %% [markdown]
# # SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8510348558840353
# MAE 0.18726926717330164

# %% [markdown]
# # ExtraTrees

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8575147571830898
# MAE 0.17111028500173395

# %% [markdown]
# # AdaBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = AdaBoostRegressor(n_estimators=15,learning_rate=1.0)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.7783584791461011
# MAE 0.22861991654810376

# %% [markdown]
# # Gradient Boost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = GradientBoostingRegressor(n_estimators=500)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8900598105450999
# MAE 0.1557006171001086

# %% [markdown]
# # XgBoost

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = XGBRegressor(n_estimators=45,max_depth=5,learning_rate=0.5)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8550774470508502
# MAE 0.17157026658787075

# %% [markdown]
# # Voting Regressor

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')


rf = RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)
gbdt = GradientBoostingRegressor(n_estimators=100,max_features=0.5)
xgb = XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5)
et = ExtraTreesRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=10)

step2 = VotingRegressor([('rf', rf), ('gbdt', gbdt), ('xgb',xgb), ('et',et)],weights=[5,1,1,1])

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8855424693714938
# MAE 0.16096801429197294

# %% [markdown]
# # Stacking

# %%
from sklearn.ensemble import VotingRegressor,StackingRegressor

step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')


estimators = [
    ('rf', RandomForestRegressor(n_estimators=350,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)),
    ('gbdt',GradientBoostingRegressor(n_estimators=100,max_features=0.5)),
    ('xgb', XGBRegressor(n_estimators=25,learning_rate=0.3,max_depth=5))
]

step2 = StackingRegressor(estimators=estimators, final_estimator=Ridge(alpha=100))

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8714778477900753
# MAE 0.16911273779185015

# %% [markdown]
# # Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,8,9])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.888803471326806
# MAE 0.15800677367165852

# %% [markdown]
# # Exporting the Model

# %%
import pickle

pickle.dump(df,open('df.pkl','wb'))
pickle.dump(pipe,open('pipe.pkl','wb'))         #### chose random forest model as r2 value is high and mae is comparatively less

# %%
pipe
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('col_tnf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   [0, 1, 7, 8, 9])])),
#                 ('step2',
#                  RandomForestRegressor(max_depth=15, max_features=0.75,
#                                        max_samples=0.5, random_state=3))])

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
df["Ram"].unique()
# Out:
# array([ 8, 16,  4,  2, 12,  6, 32, 24, 64])

# %%
df["ssd"].unique()
# Out:
# array([128,   0, 256, 512,  32,  64,   1,  16, 180, 240,   8], dtype=int64)

# %%
df["hdd"].unique()
# Out:
# array([   0,  500, 1024, 2048,   32,  128], dtype=int64)
